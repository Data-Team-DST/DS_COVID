# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
image_dataset_from_directory(
    directory="/home/cepa/DST/DS_COVID/data/processed/masked_full_dataset_256_256_L",
    labels='inferred',
    label_mode='int',
    class_names=['COVID', 'Lung_Opacity', 'Normal', 'Viral Pneumonia'],
    color_mode='grayscale',
    batch_size=32,
    image_size=(256, 256),
    shuffle=True,
    seed=42,
    validation_split=0.15,
    subset="both",
    interpolation='lanczos5',
    follow_links=False,
    crop_to_aspect_ratio=False,
    pad_to_aspect_ratio=False,
    data_format=None,
    verbose=True
)
# Out:
# Found 21165 files belonging to 4 classes.
# Using 17991 files for training.
# Using 3174 files for validation.
# 2026-01-21 23:31:44.918572: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# [<_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>,
#  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>]
